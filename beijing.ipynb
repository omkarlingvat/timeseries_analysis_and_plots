# %%
import pandas as pd

# %%
data=pd.read_csv('beijing/PRSA_Data_Aotizhongxin_20130301-20170228.csv')

# %%
data
# Out:
#           No  year  month  day  hour  PM2.5  PM10   SO2   NO2     CO    O3  \
# 0          1  2013      3    1     0    4.0   4.0   4.0   7.0  300.0  77.0
# 1          2  2013      3    1     1    8.0   8.0   4.0   7.0  300.0  77.0
# 2          3  2013      3    1     2    7.0   7.0   5.0  10.0  300.0  73.0
# 3          4  2013      3    1     3    6.0   6.0  11.0  11.0  300.0  72.0
# 4          5  2013      3    1     4    3.0   3.0  12.0  12.0  300.0  72.0
# ...      ...   ...    ...  ...   ...    ...   ...   ...   ...    ...   ...
# 35059  35060  2017      2   28    19   12.0  29.0   5.0  35.0  400.0  95.0
# 35060  35061  2017      2   28    20   13.0  37.0   7.0  45.0  500.0  81.0
# 35061  35062  2017      2   28    21   16.0  37.0  10.0  66.0  700.0  58.0
# 35062  35063  2017      2   28    22   21.0  44.0  12.0  87.0  700.0  35.0
# 35063  35064  2017      2   28    23   19.0  31.0  10.0  79.0  600.0  42.0
#
#        TEMP    PRES  DEWP  RAIN   wd  WSPM       station
# ...

# %%
data_temp=pd.DataFrame()

# %%
import numpy as np

# %%
data_temp['rollno']=[1,2,3]

# %%
data_temp['id']=[101,102,103]

# %%
data_temp['class']=['A','B','C']

# %%
data_temp.to_csv('att.csv',index=False)

# %%
data
# Out:
#           No  year  month  day  hour  PM2.5  PM10   SO2   NO2     CO    O3  \
# 0          1  2013      3    1     0    4.0   4.0   4.0   7.0  300.0  77.0
# 1          2  2013      3    1     1    8.0   8.0   4.0   7.0  300.0  77.0
# 2          3  2013      3    1     2    7.0   7.0   5.0  10.0  300.0  73.0
# 3          4  2013      3    1     3    6.0   6.0  11.0  11.0  300.0  72.0
# 4          5  2013      3    1     4    3.0   3.0  12.0  12.0  300.0  72.0
# ...      ...   ...    ...  ...   ...    ...   ...   ...   ...    ...   ...
# 35059  35060  2017      2   28    19   12.0  29.0   5.0  35.0  400.0  95.0
# 35060  35061  2017      2   28    20   13.0  37.0   7.0  45.0  500.0  81.0
# 35061  35062  2017      2   28    21   16.0  37.0  10.0  66.0  700.0  58.0
# 35062  35063  2017      2   28    22   21.0  44.0  12.0  87.0  700.0  35.0
# 35063  35064  2017      2   28    23   19.0  31.0  10.0  79.0  600.0  42.0
#
#        TEMP    PRES  DEWP  RAIN   wd  WSPM       station
# ...

# %%
data['PM10'][0:100].plot.line()

# %%
data[0:50]
# Out:
#     No  year  month  day  hour  PM2.5   PM10   SO2    NO2      CO    O3  TEMP  \
# 0    1  2013      3    1     0    4.0    4.0   4.0    7.0   300.0  77.0  -0.7
# 1    2  2013      3    1     1    8.0    8.0   4.0    7.0   300.0  77.0  -1.1
# 2    3  2013      3    1     2    7.0    7.0   5.0   10.0   300.0  73.0  -1.1
# 3    4  2013      3    1     3    6.0    6.0  11.0   11.0   300.0  72.0  -1.4
# 4    5  2013      3    1     4    3.0    3.0  12.0   12.0   300.0  72.0  -2.0
# 5    6  2013      3    1     5    5.0    5.0  18.0   18.0   400.0  66.0  -2.2
# 6    7  2013      3    1     6    3.0    3.0  18.0   32.0   500.0  50.0  -2.6
# 7    8  2013      3    1     7    3.0    6.0  19.0   41.0   500.0  43.0  -1.6
# 8    9  2013      3    1     8    3.0    6.0  16.0   43.0   500.0  45.0   0.1
# 9   10  2013      3    1     9    3.0    8.0  12.0   28.0   400.0  59.0   1.2
# 10  11  2013      3    1    10    3.0    6.0   9.0   12.0   400.0  72.0   1.9
# ...

# %%
data['PM10'].mean()
# Out:
# 110.06039131194318

# %%
data.isna().sum()
# Out:
# No            0
# year          0
# month         0
# day           0
# hour          0
# PM2.5         0
# PM10        718
# SO2         935
# NO2        1023
# CO         1776
# O3         1719
# TEMP         20
# PRES         20
# DEWP         20
# RAIN         20
# wd           81
# WSPM         14
# station       0
# dtype: int64

# %%
data.columns
# Out:
# Index(['No', 'year', 'month', 'day', 'hour', 'PM2.5', 'PM10', 'SO2', 'NO2',
#        'CO', 'O3', 'TEMP', 'PRES', 'DEWP', 'RAIN', 'wd', 'WSPM', 'station'],
#       dtype='object')

# %%
ax1=data['PM2.5'][15000:17000].plot.line()

# %%
data['PM10'].plot.line()

# %%
data['SO2'].plot.line()

# %%
data['NO2'].plot.line()

# %%
data['CO'].plot.line()

# %%
data['O3'].plot.line()

# %%
data['TEMP'].plot.line()

# %%
data['PRES'].plot.line()

# %%
data['DEWP'].plot.line()

# %%
data['RAIN'].plot.line()

# %%
data['WSPM'].plot.line()

# %%
data['PM2.5']=data["PM2.5"].rolling(min_periods=1, center=True, window=150).mean()

# %%
data
# Out:
#           No  year  month  day  hour      PM2.5  PM10   SO2   NO2     CO  \
# 0          1  2013      3    1     0   6.166667   4.0   4.0   7.0  300.0
# 1          2  2013      3    1     1   6.194444   8.0   4.0   7.0  300.0
# 2          3  2013      3    1     2   6.145833   7.0   5.0  10.0  300.0
# 3          4  2013      3    1     3   5.958333   6.0  11.0  11.0  300.0
# 4          5  2013      3    1     4   5.437500   3.0  12.0  12.0  300.0
# ...      ...   ...    ...  ...   ...        ...   ...   ...   ...    ...
# 35059  35060  2017      2   28    19  12.250000  29.0   5.0  35.0  400.0
# 35060  35061  2017      2   28    20  13.437500  37.0   7.0  45.0  500.0
# 35061  35062  2017      2   28    21  14.687500  37.0  10.0  66.0  700.0
# 35062  35063  2017      2   28    22  16.229167  44.0  12.0  87.0  700.0
# 35063  35064  2017      2   28    23  17.138889  31.0  10.0  79.0  600.0
#
#          O3  TEMP    PRES  DEWP  RAIN   wd  WSPM       station
# ...

# %%
data['PM2.5'].isna().sum()
# Out:
# 0

# %%
while (data['PM2.5'].isna().sum()>0):
    data['PM2.5']= data['PM2.5'].fillna(data['PM2.5'].rolling(4,min_periods=1).mean())

# %%
while (data['PM10'].isna().sum()>0):
    data['PM10']= data['PM10'].fillna(data['PM10'].rolling(4,min_periods=1).mean())

# %%
data['PM10']= data['PM10'].fillna(data['PM10'].rolling(4,min_periods=1).mean())

# %%
data['PM10'].isna().sum()
# Out:
# 0

# %%
data['bfill']= data['TEMP'].bfill()         # next
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-cd1fd9f5d1c0> in <module>
# ----> 1 data['bfill']= data['TEMP'].bfill()         # next
#
# NameError: name 'data' is not defined

# %%
data['TEMP']
# Out:
# 0        -0.7
# 1        -1.1
# 2        -1.1
# 3        -1.4
# 4        -2.0
#          ...
# 35059    12.5
# 35060    11.6
# 35061    10.8
# 35062    10.5
# 35063     8.6
# Name: TEMP, Length: 35064, dtype: float64

# %%
data['TEMP'].isna().sum()
# Out:
# 20
